# %% [markdown]
# <a href="https://colab.research.google.com/github/julieang/everpeak-analysis-1/blob/main/everpeak_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv(
    "https://practicum-content.s3.us-west-1.amazonaws.com/datasets/everpeak_retail.csv"
)

# %%
# 1️⃣ Reemplazar sentinels en customer_age
df['customer_age'] = df['customer_age'].replace(
    [-999, 999, 0, -1],
    pd.NA
)

# 2️⃣ Asegurar tipo numérico e imputar con la mediana
df['customer_age'] = pd.to_numeric(df['customer_age'], errors='coerce')
df['customer_age'] = df['customer_age'].fillna(df['customer_age'].median())

# 3️⃣ Imputar valores categóricos
df['city'] = df['city'].fillna('unknown')
df['state'] = df['state'].fillna('unknown')

# 4️⃣ Convertir fechas y eliminar registros inválidos
df['order_date'] = pd.to_datetime(df['order_date'], errors='coerce')
df = df.dropna(subset=['order_date'])

# %%
df.to_csv("everpeak_clean.csv", index=False)

# %%
df = pd.read_csv("everpeak_clean.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

df = pd.read_csv("everpeak_clean.csv")
df.head()
# Out:
#    order_id  order_date  customer_id product_category  price  quantity  \
# 0         1  2024-02-02         2616           Sports    269        50
# 1         2  2024-10-10         1736          Grocery     66         0
# 2         3  2024-08-27         2543           Sports    267         0
# 3         4  2024-06-09         2252             Toys    114       125
# 4         5  2024-06-07         1583          Fashion    729        16
#
#    order_value payment_method         city state  customer_age
# 0        13385    credit_card     New York    NY          66.0
# 1          660     debit_card  Los Angeles    CA          24.0
# 2         5073    credit_card      Chicago    IL          23.0
# 3        14290    credit_card     New York    NY          70.0
# 4        11754    credit_card      Houston    TX          75.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
['order_id',
 'order_date',
 'customer_id',
 'product_category',
 'price',
 'quantity',
 'order_value',
 'payment_method',
 'city',
 'state',
 'customer_age']
# Out:
# ['order_id',
#  'order_date',
#  'customer_id',
#  'product_category',
#  'price',
#  'quantity',
#  'order_value',
#  'payment_method',
#  'city',
#  'state',
#  'customer_age']

# %%
import matplotlib.pyplot as plt

plt.hist(df['order_value'], bins=10, edgecolor='black')
plt.xlabel('Valor del pedido')
plt.ylabel('Cantidad de pedidos')
plt.title('Distribución del valor de pedidos')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['order_value'], bins=10, kde=True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_math = pd.read_csv(
    "https://practicum-content.s3.us-west-1.amazonaws.com/datasets/math_class.csv"
)

plt.hist(df_math['score'], bins=10, color='skyblue', edgecolor='black')
plt.title('Distribución de notas con 10 bins')
plt.xlabel("Notas")
plt.ylabel("Cantidad de estudiantes")
plt.show()

# %%
plt.hist(df_math['score'], bins=5, color='skyblue', edgecolor='black')
plt.title('Distribución de notas con 5 bins')
plt.xlabel("Notas")
plt.ylabel("Cantidad de estudiantes")
plt.show()

# %%
plt.hist(df_math['score'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribución de notas con 30 bins')
plt.xlabel("Notas")
plt.show()

# %%
counts, bin_edges, _ = plt.hist(
    df_math['score'],
    bins=10,
    color='skyblue',
    edgecolor='black'
)

plt.xticks(bin_edges)  # usamos los bordes reales como etiquetas
plt.show()

# %%
import numpy as np

n = df_math['score'].count()
bins_raiz = int(np.sqrt(n))
bins_raiz
# Out:
# 17

# %%
plt.hist(df_math['score'], bins=bins_raiz, color='skyblue', edgecolor='black')
plt.title('Distribución de notas (bins por raíz cuadrada)')
plt.xlabel("Notas")
plt.ylabel("Cantidad de estudiantes")
plt.show()

# %%
df['price'].describe()
# Out:
# count     5000.000000
# mean       756.387400
# std       1173.265182
# min         12.000000
# 25%        218.000000
# 50%        457.000000
# 75%        847.250000
# max      36708.000000
# Name: price, dtype: float64

# %%
plt.hist(df['price'], bins=30, color='skyblue', edgecolor='black')
plt.xlim(0, 200)
plt.title('Distribución de price (sin outliers extremos)')
plt.xlabel("Precio")
plt.ylabel("Cantidad de productos")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("everpeak_clean.csv")

plt.hist(df['price'], bins=10, color='skyblue', edgecolor='black')
plt.title('Histograma de precios sin ajuste')
plt.xlabel("Precio")
plt.ylabel("Cantidad")
plt.show()

# %%
plt.hist(df['price'], bins=10, range=(12,1000), color='skyblue', edgecolor='black')
plt.title('Histograma de precios con ajuste de eje X')
plt.show()

# %%
counts, bin_edges, _ = plt.hist(
    df['price'],
    bins=10,
    range=(12,1000),
    color='skyblue',
    edgecolor='black'
)
plt.xticks(bin_edges)
plt.title('Histograma de precios con ajuste de eje X')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(
    "https://practicum-content.s3.us-west-1.amazonaws.com/datasets/everpeak_clean.csv"
)

# %%
plt.hist(df['order_value'], bins=10, color='skyblue', edgecolor='black')
plt.title('Histograma de order_value sin ajuste')
plt.xlabel('Order value')
plt.ylabel('Count')
plt.show()

# %%
df['order_value'].describe()
# Out:
# count      5000.000000
# mean      10075.523800
# std       12406.603152
# min          12.000000
# 25%        3094.000000
# 50%       10341.000000
# 75%       13160.500000
# max      303824.000000
# Name: order_value, dtype: float64

# %%
plt.hist(df['order_value'], bins=10, range=(12, 15000), color='skyblue', edgecolor='black')
plt.title('Histograma de order_value con zoom')
plt.xlabel('Order value')
plt.ylabel('Count')
plt.show()

# %%
import matplotlib.pyplot as plt

counts, bin_edges, _ = plt.hist(
    df['order_value'],
    bins=10,
    range=(12, 15000),
    color='skyblue',
    edgecolor='black'
)

plt.xticks(bin_edges)
plt.title('Histograma de order_value con zoom')
plt.xlabel('Order value')
plt.ylabel('Count')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x=df['order_value'], color='skyblue')
plt.title('Boxplot de order_value')
plt.xlabel('Order value')
plt.show()

# %%
Q1 = df['price'].quantile(0.25)
print('Primer cuartil:', Q1)
# Out:
# Primer cuartil: 218.0

# %%
Q3 = df['price'].quantile(0.75)
print('Tercer cuartil:', Q3)
# Out:
# Tercer cuartil: 847.25

# %%
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1

# %%
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

print('Límite inferior:', lower)
print('Límite superior:', upper)
# Out:
# Límite inferior: -725.875
# Límite superior: 1791.125

# %%
outliers = df[(df['price'] < lower) | (df['price'] > upper)]
outliers[['price']]
# Out:
#       price
# 64     2106
# 67     5181
# 95     1940
# 123    1947
# 138    2437
# ...     ...
# 4955   3824
# 4974   1985
# 4984   1911
# 4990   2856
# 4997   2699
#
# [446 rows x 1 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x=df['price'], color='skyblue')
plt.title('Boxplot de precios')
plt.xlabel('Precio')
plt.show()

# %%
mean = df['price'].mean()
std = df['price'].std()

df['z'] = (df['price'] - mean) / std

# Ver outliers según Z-score
df[df['z'].abs() > 3]

# Revisar distribución del Z-score
df['z'].describe()
# Out:
# count    5.000000e+03
# mean     3.836931e-17
# std      1.000000e+00
# min     -6.344579e-01
# 25%     -4.588796e-01
# 50%     -2.551745e-01
# 75%      7.744421e-02
# max      3.064236e+01
# Name: z, dtype: float64

# %%
import pandas as pd

df = pd.read_csv("/content/everpeak_clean.csv")
df["order_value"].describe()
# Out:
# count      5000.000000
# mean      10075.523800
# std       12406.603152
# min          12.000000
# 25%        3094.000000
# 50%       10341.000000
# 75%       13160.500000
# max      303824.000000
# Name: order_value, dtype: float64

# %%
lower = df["order_value"].quantile(0.05)
upper = df["order_value"].quantile(0.95)

print("Límite inferior (5%):", lower)
print("Límite superior (95%):", upper)
# Out:
# Límite inferior (5%): 522.0
# Límite superior (95%): 21700.850000000006

# %%
df["order_value_wins"] = df["order_value"].clip(lower=lower, upper=upper)

# %%
print("Antes (original):")
print(df["order_value"].describe())

print("\nDespués (winsorizado):")
print(df["order_value_wins"].describe())
# Out:
# Antes (original):
# count      5000.000000
# mean      10075.523800
# std       12406.603152
# min          12.000000
# 25%        3094.000000
# 50%       10341.000000
# 75%       13160.500000
# max      303824.000000
# Name: order_value, dtype: float64
#
# Después (winsorizado):
# count     5000.000000
# mean      8907.579100
# std       5902.219544
# min        522.000000
# 25%       3094.000000
# 50%      10341.000000
# 75%      13160.500000
# max      21700.850000
# Name: order_value_wins, dtype: float64

# %%
upper = df['order_value'].quantile(0.99)
upper
# Out:
# np.float64(56150.67000000012)

# %%
df['order_value_winsor'] = np.clip(df['order_value'], lower, upper)

# %%
import numpy as np

df['order_value_winsor'] = np.clip(
    df['order_value'],
    df['order_value'].min(),
    upper
)

df[['order_value', 'order_value_winsor']].head()
# Out:
#    order_value  order_value_winsor
# 0        13385             13385.0
# 1          660               660.0
# 2         5073              5073.0
# 3        14290             14290.0
# 4        11754             11754.0

# %%
import numpy as np

# calculo percentil 1 y 99
lower = df['order_value'].quantile(0.01)
upper = df['order_value'].quantile(0.99)

# crear columna con valores capados
df['order_value_winsor'] = np.clip(df['order_value'], lower, upper)

# comparar distribuciones
df[["order_value", "order_value_winsor"]].describe()
# Out:
#          order_value  order_value_winsor
# count    5000.000000         5000.000000
# mean    10075.523800         9695.544500
# std     12406.603152         8676.466743
# min        12.000000          192.000000
# 25%      3094.000000         3094.000000
# 50%     10341.000000        10341.000000
# 75%     13160.500000        13160.500000
# max    303824.000000        56150.670000

# %%
Q1 = df['order_value'].quantile(0.25)
Q3 = df['order_value'].quantile(0.75)
IQR = Q3 - Q1
upper = Q3 + 1.5 * IQR

outliers = df[df['order_value'] > upper]

# %%
sns.histplot(df['order_value'])
plt.show()

sns.boxplot(x=df['order_value'])
plt.show()

# %%
import pandas as pd
import numpy as np

# %%
lower = df['price'].quantile(0.01)
upper = df['price'].quantile(0.99)

# %%
import pandas as pd
import numpy as np


# calculo percentil 1 y 99
lower = df['price'].quantile(0.01)
upper = df['price'].quantile(0.99)

# crear columna con valores capados (winsorizados)
df['price_winsor'] = np.clip(df['price'], lower, upper)

# %%
# Ejemplo: Clasificar una Venta
valor_venta = 150

#Si la venta es mayor a 100, imprime "Venta Alta"
if valor_venta > 100:
    print("Venta alta")
# Out:
# Venta alta

# %%
# Ejemplo: Clasificar una Venta
valor_venta = 50

#Si la venta es mayor a 100, imprime "Venta Alta"
if valor_venta > 100:
    print("Venta alta")

print("Código terminado")
# Out:
# Código terminado

# %%
#Si la venta es mayor a 100, imprime "Venta Alta"
if valor_venta > 100:
    print("Venta alta")

# %%
# Ejemplo: Clasificar una Venta
valor_venta = 150

#Si la venta es mayor a 100, imprime "Venta Alta"
if valor_venta > 100:
    print("Venta alta")
#Caso contrario, imprime "Venta Baja"
else:
    print("Venta baja")

print("Código terminado")
# Out:
# Venta alta
# Código terminado

# %%
# Clasificar puntuación de un producto
puntuacion = 7.5

if puntuacion >= 9:
    clasificacion = "Excelente"
else:
    clasificacion = "Mala"

print(clasificacion)
# Out:
# Mala

# %%
# Clasificar puntuación de un producto
puntuacion = 7.5

if puntuacion >= 9:
    clasificacion = "Excelente"
elif puntuacion >= 7:
    clasificacion = "Buena"
else:
    clasificacion = "Mala"

# %%
# Clasificar puntuación de un producto
puntuacion = 7.5

if puntuacion >= 9:
    clasificacion = "Excelente"
elif puntuacion >= 7:
    clasificacion = "Buena"
elif puntuacion >= 5:
    clasificacion = "Regular"
else:
    clasificacion = "Mala"

print(clasificacion )
# Out:
# Buena

# %%
#calculamos el promedio
edad_promedio = df['customer_age'].mean()
print("Edad promedio:", edad_promedio)
# Out:
# Edad promedio: 49.1208

# %%
# Si la edad promedio es mayor a 55
if edad_promedio > 55:
    print("Clientes senior")
#Si la edad es menor o igual a 55
else:
    print ("Clientes junior")
# Out:
# Clientes junior

# %%
#calculamos el promedio
gasto_promedio = df['order_value'].mean()
print("Gasto promedio:", gasto_promedio )
# Out:
# Gasto promedio: 10075.5238

# %%
# Clasificar clientes según el gasto mediano
if gasto_promedio > 10000:
    print("Clientes: VIP")
elif gasto_promedio > 5000:
    print("Clientes: Medium Value")
else:
    print("Clientes: Low Value")
# Out:
# Clientes: VIP

# %%
df["customer_segment"] = np.where(df['customer_age'] >= 55, "Senior", "otro")
df[["customer_age", "order_value", "customer_segment"]].head(5)
# Out:
#    customer_age  order_value customer_segment
# 0          66.0        13385           Senior
# 1          24.0          660             otro
# 2          23.0         5073             otro
# 3          70.0        14290           Senior
# 4          75.0        11754           Senior

# %%
df["customer_segment"] = np.where(
    (df['customer_age'] >= 55) & (df['order_value'] >= 10000), "Senior VIP", "otro")

df[["customer_age", "order_value", "customer_segment"]].head(5)
# Out:
#    customer_age  order_value customer_segment
# 0          66.0        13385       Senior VIP
# 1          24.0          660             otro
# 2          23.0         5073             otro
# 3          70.0        14290       Senior VIP
# 4          75.0        11754       Senior VIP

# %%
df["customer_segment"] = np.where(
    (df['customer_age'] >= 55) & (df['order_value'] >= 10000), "Senior VIP",
        np.where((df['customer_age'] < 55) & (df['order_value'] >= 10000), "Junior VIP", "otro"))

df[["customer_age", "order_value", "customer_segment"]].head(10)
# Out:
#    customer_age  order_value customer_segment
# 0          66.0        13385       Senior VIP
# 1          24.0          660             otro
# 2          23.0         5073             otro
# 3          70.0        14290       Senior VIP
# 4          75.0        11754       Senior VIP
# 5          57.0        13347       Senior VIP
# 6          75.0        10868       Senior VIP
# 7          38.0         2862             otro
# 8          40.0        45819       Junior VIP
# 9          28.0        23940       Junior VIP

# %%
df['customer_segment'] = np.where(
    (df['customer_age'] >= 55) & (df['order_value'] >= 10000), "Senior VIP",
        np.where((df['customer_age'] < 55) & (df['order_value'] >= 10000), "Junior VIP",
            np.where((df['customer_age'] >= 55) & (df['order_value'] >= 5000), "Sr. Medium Value",
                np.where((df['customer_age'] < 55) & (df['order_value'] >= 5000), "Jr. Medium Value",
                    np.where(df['order_value'] < 5000, "Low Value", "Error")
                        )
                    )
                )
)

df[["customer_age", "order_value", "customer_segment"]].head(10)
# Out:
#    customer_age  order_value  customer_segment
# 0          66.0        13385        Senior VIP
# 1          24.0          660         Low Value
# 2          23.0         5073  Jr. Medium Value
# 3          70.0        14290        Senior VIP
# 4          75.0        11754        Senior VIP
# 5          57.0        13347        Senior VIP
# 6          75.0        10868        Senior VIP
# 7          38.0         2862         Low Value
# 8          40.0        45819        Junior VIP
# 9          28.0        23940        Junior VIP

# %%
df['customer_segment'].value_counts()
# Out:
# customer_segment
# Senior VIP          2002
# Low Value           1697
# Jr. Medium Value     651
# Junior VIP           650
# Name: count, dtype: int64

# %%
def classify_segment(row):
    return "otro"

# aplicar función y ver cambios
df["customer_segment"] = df.apply(classify_segment, axis=1)
df[["customer_age", "order_value", "customer_segment"]].head()
# Out:
#    customer_age  order_value customer_segment
# 0          66.0        13385             otro
# 1          24.0          660             otro
# 2          23.0         5073             otro
# 3          70.0        14290             otro
# 4          75.0        11754             otro

# %%
# Función para clasificar clientes
def classify_segment(row):
    age = row['customer_age']
    spend = row['order_value']

# aplicar función y ver cambios
df["customer_segment"] = df.apply(classify_segment, axis=1)
df[["customer_age", "order_value", "customer_segment"]].head()
# Out:
#    customer_age  order_value customer_segment
# 0          66.0        13385             None
# 1          24.0          660             None
# 2          23.0         5073             None
# 3          70.0        14290             None
# 4          75.0        11754             None

# %%
# Función para clasificar clientes
def classify_segment(row):
    age = row['customer_age']
    spend = row['order_value']

    if spend >= 10000:
        return "VIP"
    else:
        return "Low Value"

# aplicar función y ver cambios
df["customer_segment"] = df.apply(classify_segment, axis=1)
df[["customer_age", "order_value", "customer_segment"]].head()
# Out:
#    customer_age  order_value customer_segment
# 0          66.0        13385              VIP
# 1          24.0          660        Low Value
# 2          23.0         5073        Low Value
# 3          70.0        14290              VIP
# 4          75.0        11754              VIP

# %%
# Función para clasificar clientes
def classify_segment(row):
    age = row['customer_age']
    spend = row['order_value']

    if spend >= 10000:
        return "VIP"
    else:
        return "Low Value"

# aplicar función y ver cambios
df["customer_segment"] = df.apply(classify_segment, axis=1)
df[["customer_age", "order_value", "customer_segment"]].head()
# Out:
#    customer_age  order_value customer_segment
# 0          66.0        13385              VIP
# 1          24.0          660        Low Value
# 2          23.0         5073        Low Value
# 3          70.0        14290              VIP
# 4          75.0        11754              VIP

# %%
# Función para clasificar clientes
def classify_segment(row):
    age = row['customer_age']
    spend = row['order_value']

    # Segmentación de Alto Valor (Gasto >= 10000)
    if spend >= 10000:
        return "VIP"
    # Segmentación de Valor Medio (Gasto entre 5000 y 9999)
    elif spend >= 5000:
        return "Medium Value"
    # Segmentación de Valor Bajo (Gasto < 5000)
    else:
        return "Low Value"

# aplicar función y ver cambios
df["customer_segment"] = df.apply(classify_segment, axis=1)
df[["customer_age", "order_value", "customer_segment"]].head()
# Out:
#    customer_age  order_value customer_segment
# 0          66.0        13385              VIP
# 1          24.0          660        Low Value
# 2          23.0         5073     Medium Value
# 3          70.0        14290              VIP
# 4          75.0        11754              VIP

# %%
# Función para clasificar clientes
def classify_segment(row):
    age = row['customer_age']
    spend = row['order_value']

    # Segmentación de Alto Valor (Gasto >= 10000)
    if spend >= 10000:
        if age >= 55:
            return "Senior VIP"
        else: # age < 55
            return "Junior VIP"

    # Segmentación de Valor Medio (Gasto entre 5000 y 9999)
    elif spend >= 5000:
        if age >= 55:
            return "Sr. Medium Value"
        else: # age < 55
            return "Jr. Medium Value"

    # Segmentación de Valor Bajo (Gasto < 5000)
    else: # spend < 5000
        return "Low Value"

# aplicar función y ver cambios
df["customer_segment"] = df.apply(classify_segment, axis=1)
df[["customer_age", "order_value", "customer_segment"]].head()
# Out:
#    customer_age  order_value  customer_segment
# 0          66.0        13385        Senior VIP
# 1          24.0          660         Low Value
# 2          23.0         5073  Jr. Medium Value
# 3          70.0        14290        Senior VIP
# 4          75.0        11754        Senior VIP

# %%
# Función para clasificar clientes
def classify_segment(row):
    age = row['customer_age']
    spend = row['order_value']

    # Manejo de valores nulos/faltantes
    if pd.isna(age) or pd.isna(spend):
        return "Error en Datos"

    # Segmentación
    if spend >= 10000 and age >= 55:
        return "Senior VIP"
    elif spend >= 10000 and age < 55:
        return "Junior VIP"
    elif spend >= 5000 and age >= 55:
        return "Sr. Medium Value"
    elif spend >= 5000 and age < 55:
        return "Jr. Medium Value"
    else:
        return "Low Value"

# %%
# importar librerías y dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            5000 non-null   int64
#  1   order_date          5000 non-null   object
#  2   customer_id         5000 non-null   int64
#  3   product_category    5000 non-null   object
#  4   price               5000 non-null   int64
#  5   quantity            5000 non-null   int64
#  6   order_value         5000 non-null   int64
#  7   payment_method      5000 non-null   object
#  8   city                5000 non-null   object
#  9   state               5000 non-null   object
#  10  customer_age        5000 non-null   float64
#  11  order_value_wins    5000 non-null   float64
#  12  order_value_winsor  5000 non-null   float64
#  13  price_winsor        5000 non-null   float64
#  14  customer_segment    5000 non-null   object
# ...

# %%
num_cols = ["price", "quantity", "order_value", "customer_age"]
df[num_cols].describe()
# Out:
#               price     quantity    order_value  customer_age
# count   5000.000000  5000.000000    5000.000000   5000.000000
# mean     756.387400    21.879200   10075.523800     49.120800
# std     1173.265182    63.344698   12406.603152     17.710679
# min       12.000000     0.000000      12.000000     18.000000
# 25%      218.000000     0.000000    3094.000000     34.000000
# 50%      457.000000     0.000000   10341.000000     49.000000
# 75%      847.250000    22.000000   13160.500000     64.000000
# max    36708.000000  1266.000000  303824.000000     80.000000

# %%
# Graficar histogramas
for col in num_cols:
    plt.figure(figsize=(9, 3))
    sns.histplot(df[col], bins=60)
    plt.title(f'Distribución de la variable {col}')
    plt.show()

# %%
# Graficar boxplots
for col in num_cols:
    plt.figure(figsize=(9,3))
    sns.boxplot(x=df[col])
    plt.title(f'Distribución de la variable {col}')
    plt.show()

# %%
for col in num_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    print(col, "IQR: ", IQR)

    upper = Q3 + 1.5*IQR
    lower = Q1 - 1.5*IQR
    display(df[(df['price'] > upper) | (df['price'] < lower)])
# Out:
# price IQR:  629.25
#       order_id  order_date  customer_id product_category  price  quantity  \
# 64          65  2024-05-30         1651           Sports   2106         5
# 67          68  2024-05-15         2385             Home   5181         0
# 95          96  2024-04-15         2991           Sports   1940         0
# 123        124  2024-06-21         1389      Electronics   1947         0
# 138        139  2024-05-07         2274      Electronics   2437         6
# ...        ...         ...          ...              ...    ...       ...
# 4955      4956  2024-03-11         2230      Electronics   3824         0
# 4974      4975  2024-10-20         2627      Electronics   1985         6
# 4984      4985  2024-03-11         2509           Sports   1911         0
# 4990      4991  2024-08-25         2569           Sports   2856         5
# 4997      4998  2024-10-26         2838      Electronics   2699         4
#
# ...

# %%
for col in num_cols:
    p99 = df[col].quantile(0.99)
    df[f'{col}_capped'] = np.clip(df[col], None, p99)

df[["price","price_capped", "quantity","quantity_capped",
    "order_value","order_value_capped", "customer_age","customer_age_capped"]].head()
# Out:
#    price  price_capped  quantity  quantity_capped  order_value  \
# 0    269         269.0        50               50        13385
# 1     66          66.0         0                0          660
# 2    267         267.0         0                0         5073
# 3    114         114.0       125              125        14290
# 4    729         729.0        16               16        11754
#
#    order_value_capped  customer_age  customer_age_capped
# 0             13385.0          66.0                 66.0
# 1               660.0          24.0                 24.0
# 2              5073.0          23.0                 23.0
# 3             14290.0          70.0                 70.0
# 4             11754.0          75.0                 75.0

# %%
df[["price","price_capped", "quantity","quantity_capped",
    "order_value","order_value_capped", "customer_age","customer_age_capped"]].describe()
# Out:
#               price  price_capped     quantity  quantity_capped  \
# count   5000.000000   5000.000000  5000.000000      5000.000000
# mean     756.387400    725.998400    21.879200        19.804200
# std     1173.265182    877.342942    63.344698        43.358315
# min       12.000000     12.000000     0.000000         0.000000
# 25%      218.000000    218.000000     0.000000         0.000000
# 50%      457.000000    457.000000     0.000000         0.000000
# 75%      847.250000    847.250000    22.000000        22.000000
# max    36708.000000   5148.120000  1266.000000       260.000000
#
#          order_value  order_value_capped  customer_age  customer_age_capped
# count    5000.000000         5000.000000   5000.000000          5000.000000
# mean    10075.523800         9694.762100     49.120800            49.120800
# std     12406.603152         8677.328642     17.710679            17.710679
# min        12.000000           12.000000     18.000000            18.000000
# ...

# %%
df['order_value'].describe()
# Out:
# count      5000.000000
# mean      10075.523800
# std       12406.603152
# min          12.000000
# 25%        3094.000000
# 50%       10341.000000
# 75%       13160.500000
# max      303824.000000
# Name: order_value, dtype: float64

# %%
sns.histplot(df['order_value'], bins=60)
# Out:
# <Axes: xlabel='order_value', ylabel='Count'>

# %%
df['order_value'].describe()
# Out:
# count      5000.000000
# mean      10075.523800
# std       12406.603152
# min          12.000000
# 25%        3094.000000
# 50%       10341.000000
# 75%       13160.500000
# max      303824.000000
# Name: order_value, dtype: float64

# %%
sns.boxplot(x=df['order_value'])
# Out:
# <Axes: xlabel='order_value'>

# %%
p99 = df['order_value'].quantile(0.99)

df['order_value_capped'] = np.where(
    df['order_value'] > p99,
    p99,
    df['order_value']
)

sns.boxplot(x=df['order_value_capped'])
# Out:
# <Axes: xlabel='order_value_capped'>

# %%
df['order_value_capped'].describe()
# Out:
# count     5000.000000
# mean      9694.762100
# std       8677.328642
# min         12.000000
# 25%       3094.000000
# 50%      10341.000000
# 75%      13160.500000
# max      56150.670000
# Name: order_value_capped, dtype: float64

# %%
# Nuevo análisis: detectar outliers con IQR
Q1 = df['order_value'].quantile(0.25)
Q3 = df['order_value'].quantile(0.75)
IQR = Q3 - Q1
upper = Q3 + 1.5*IQR
df['outlier_flag'] = df['order_value'] > upper

# %%
# Missingness analysis by column
missingness = (
    df.isna()
      .sum()
      .to_frame(name='missing_count')
)

missingness['missing_pct'] = (
    missingness['missing_count'] / len(df) * 100
)

missingness.sort_values('missing_pct', ascending=False)
# Out:
#                      missing_count  missing_pct
# order_id                         0          0.0
# order_date                       0          0.0
# customer_id                      0          0.0
# product_category                 0          0.0
# price                            0          0.0
# quantity                         0          0.0
# order_value                      0          0.0
# payment_method                   0          0.0
# city                             0          0.0
# state                            0          0.0
# customer_age                     0          0.0
# order_value_wins                 0          0.0
# order_value_winsor               0          0.0
# price_winsor                     0          0.0
# customer_segment                 0          0.0
# price_capped                     0          0.0
# quantity_capped                  0          0.0
# order_value_capped               0          0.0
# customer_age_capped              0          0.0
# ...

# %% [markdown]
# ## Missingness Analysis
